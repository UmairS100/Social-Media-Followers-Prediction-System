# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df = pd.read_csv('data.csv')

# %%
data=pd.read_csv('data.csv')
data
# Out:
#    period_start  period_end  followers_gained  followers_lost  followers_net  \
# 0      05-01-20   5/31/2020                 1               0              1
# 1      06-01-20   6/30/2020                 8               0              8
# 2      07-01-20   7/31/2020               103               0            103
# 3      08-01-20   8/31/2020                46               0             46
# 4      09-01-20   9/30/2020                35               1             34
# 5      10-01-20  10/31/2020                30               0             30
# 6      11-01-20  11/30/2020               311               1            310
# 7      12-01-20  12/31/2020               217               0            217
# 8      01-01-21   1/31/2021               826               1            825
# 9      02-01-21   2/28/2021               394               1            393
# 10     03-01-21   3/31/2021               390               2            388
# 11     04-01-21   4/30/2021               454               2            452
# 12     05-01-21   5/31/2021               462               7            455
# 13     06-01-21   6/30/2021               595               3            592
# 14     07-01-21   7/31/2021               541               5            536
# 15     08-01-21   8/31/2021                57               0             57
#
#     followers_total  subscribers_gained  subscribers_lost  subscribers_net  \
# 0                 1                   0                 0                0
# 1                 9                   0                 0                0
# 2               112                   0                 0                0
# 3               158                   0                 0                0
# 4               192                   0                 0                0
# 5               222                   0                 0                0
# 6               532                   3                 0                3
# 7               749                  10                 1                9
# 8              1574                  14                 1               13
# 9              1967                   7                 0                7
# 10             2355                   7                 2                5
# 11             2807                   8                 0                8
# 12             3262                   6                 0                6
# 13             3854                   5                 0                5
# 14             4390                  20                 6               14
# 15             4447                   6                 2                4
#
#     subscribers_total     views
# 0                   0     128.0
# 1                   0   16130.0
# 2                   0   14616.0
# 3                   0    4053.0
# 4                   0    5153.0
# 5                   0   16029.0
# 6                   3   59976.0
# 7                  12   76322.0
# 8                  25  108962.0
# 9                  32  100650.0
# 10                 37  102987.0
# 11                 45  134765.0
# 12                 51  167608.0
# 13                 56  154235.0
# 14                 70  144167.0
# 15                 74       NaN

# %%
data.head()
# Out:
#   period_start period_end  followers_gained  followers_lost  followers_net  \
# 0     05-01-20  5/31/2020                 1               0              1
# 1     06-01-20  6/30/2020                 8               0              8
# 2     07-01-20  7/31/2020               103               0            103
# 3     08-01-20  8/31/2020                46               0             46
# 4     09-01-20  9/30/2020                35               1             34
#
#    followers_total  subscribers_gained  subscribers_lost  subscribers_net  \
# 0                1                   0                 0                0
# 1                9                   0                 0                0
# 2              112                   0                 0                0
# 3              158                   0                 0                0
# 4              192                   0                 0                0
#
#    subscribers_total    views
# 0                  0    128.0
# 1                  0  16130.0
# 2                  0  14616.0
# 3                  0   4053.0
# 4                  0   5153.0

# %%
plt.figure(figsize=(15, 10))
sns.set_theme(style="whitegrid")
plt.title("Number of Followers I Gained Every Month")
sns.barplot(x="followers_gained", y="period_end", data=data)
plt.show()

# %%
plt.figure(figsize=(15, 10))
sns.set_theme(style="whitegrid")
plt.title("Total Followers At The End of Every Month")
sns.barplot(x="followers_total", y="period_end", data=data)
plt.show()

# %%
plt.figure(figsize=(15, 10))
sns.set_theme(style="whitegrid")
plt.title("Number of Followers I Lost Every Month")
sns.barplot(x="followers_lost", y="period_end", data=data)
plt.show()

# %%
plt.figure(figsize=(15, 10))
sns.set_theme(style="whitegrid")
plt.title("Total Views Every Month")
sns.barplot(x="views", y="period_end", data=data)
plt.show()

# %%
data.set_index('followers_gained')
# Out:
#                  period_start  period_end  followers_lost  followers_net  \
# followers_gained
# 1                    05-01-20   5/31/2020               0              1
# 8                    06-01-20   6/30/2020               0              8
# 103                  07-01-20   7/31/2020               0            103
# 46                   08-01-20   8/31/2020               0             46
# 35                   09-01-20   9/30/2020               1             34
# 30                   10-01-20  10/31/2020               0             30
# 311                  11-01-20  11/30/2020               1            310
# 217                  12-01-20  12/31/2020               0            217
# 826                  01-01-21   1/31/2021               1            825
# 394                  02-01-21   2/28/2021               1            393
# 390                  03-01-21   3/31/2021               2            388
# 454                  04-01-21   4/30/2021               2            452
# 462                  05-01-21   5/31/2021               7            455
# 595                  06-01-21   6/30/2021               3            592
# 541                  07-01-21   7/31/2021               5            536
# 57                   08-01-21   8/31/2021               0             57
#
#                   followers_total  subscribers_gained  subscribers_lost  \
# followers_gained
# 1                               1                   0                 0
# 8                               9                   0                 0
# 103                           112                   0                 0
# 46                            158                   0                 0
# 35                            192                   0                 0
# 30                            222                   0                 0
# 311                           532                   3                 0
# 217                           749                  10                 1
# 826                          1574                  14                 1
# 394                          1967                   7                 0
# 390                          2355                   7                 2
# 454                          2807                   8                 0
# 462                          3262                   6                 0
# 595                          3854                   5                 0
# 541                          4390                  20                 6
# 57                           4447                   6                 2
#
#                   subscribers_net  subscribers_total     views
# followers_gained
# 1                               0                  0     128.0
# 8                               0                  0   16130.0
# 103                             0                  0   14616.0
# 46                              0                  0    4053.0
# 35                              0                  0    5153.0
# 30                              0                  0   16029.0
# 311                             3                  3   59976.0
# 217                             9                 12   76322.0
# 826                            13                 25  108962.0
# 394                             7                 32  100650.0
# 390                             5                 37  102987.0
# 454                             8                 45  134765.0
# 462                             6                 51  167608.0
# 595                             5                 56  154235.0
# 541                            14                 70  144167.0
# 57                              4                 74       NaN

# %%
pip install autots

# %%
from autots import AutoTS

# %%
model=AutoTS(forecast_length=2, frequency='infer', ensemble='simple')

# %%
model=model.fit(data, date_col='period_end',value_col='followers_gained',id_col=None)

# %%
prediction=model.predict()
# Out:
# C:\Users\Umair\anaconda3\Lib\site-packages\statsmodels\genmod\generalized_linear_model.py:813: RuntimeWarning: divide by zero encountered in scalar divide
#   return np.sum(resid / self.family.variance(mu)) / self.df_resid
# C:\Users\Umair\anaconda3\Lib\site-packages\statsmodels\genmod\generalized_linear_model.py:1257: PerfectSeparationWarning: Perfect separation or prediction detected, parameter may not be identified
#   warnings.warn(msg, category=PerfectSeparationWarning)
# C:\Users\Umair\anaconda3\Lib\site-packages\statsmodels\genmod\generalized_linear_model.py:1257: PerfectSeparationWarning: Perfect separation or prediction detected, parameter may not be identified
#   warnings.warn(msg, category=PerfectSeparationWarning)
# C:\Users\Umair\anaconda3\Lib\site-packages\statsmodels\genmod\generalized_linear_model.py:1257: PerfectSeparationWarning: Perfect separation or prediction detected, parameter may not be identified
#   warnings.warn(msg, category=PerfectSeparationWarning)
# C:\Users\Umair\anaconda3\Lib\site-packages\statsmodels\genmod\generalized_linear_model.py:1257: PerfectSeparationWarning: Perfect separation or prediction detected, parameter may not be identified
#   warnings.warn(msg, category=PerfectSeparationWarning)
# C:\Users\Umair\anaconda3\Lib\site-packages\statsmodels\genmod\generalized_linear_model.py:1257: PerfectSeparationWarning: Perfect separation or prediction detected, parameter may not be identified
#   warnings.warn(msg, category=PerfectSeparationWarning)
# C:\Users\Umair\anaconda3\Lib\site-packages\statsmodels\genmod\generalized_linear_model.py:1257: PerfectSeparationWarning: Perfect separation or prediction detected, parameter may not be identified
#   warnings.warn(msg, category=PerfectSeparationWarning)
# C:\Users\Umair\anaconda3\Lib\site-packages\statsmodels\genmod\generalized_linear_model.py:1257: PerfectSeparationWarning: Perfect separation or prediction detected, parameter may not be identified
#   warnings.warn(msg, category=PerfectSeparationWarning)

# %%
forecast=prediction.forecast

# %%
print(forecast)
# Out:
#             followers_gained
# 2021-09-30        175.916667
# 2021-10-31        156.763317

# %%
data.set_index('followers_lost')
# Out:
#                period_start  period_end  followers_gained  followers_net  \
# followers_lost
# 0                  05-01-20   5/31/2020                 1              1
# 0                  06-01-20   6/30/2020                 8              8
# 0                  07-01-20   7/31/2020               103            103
# 0                  08-01-20   8/31/2020                46             46
# 1                  09-01-20   9/30/2020                35             34
# 0                  10-01-20  10/31/2020                30             30
# 1                  11-01-20  11/30/2020               311            310
# 0                  12-01-20  12/31/2020               217            217
# 1                  01-01-21   1/31/2021               826            825
# 1                  02-01-21   2/28/2021               394            393
# 2                  03-01-21   3/31/2021               390            388
# 2                  04-01-21   4/30/2021               454            452
# 7                  05-01-21   5/31/2021               462            455
# 3                  06-01-21   6/30/2021               595            592
# 5                  07-01-21   7/31/2021               541            536
# 0                  08-01-21   8/31/2021                57             57
#
#                 followers_total  subscribers_gained  subscribers_lost  \
# followers_lost
# 0                             1                   0                 0
# 0                             9                   0                 0
# 0                           112                   0                 0
# 0                           158                   0                 0
# 1                           192                   0                 0
# 0                           222                   0                 0
# 1                           532                   3                 0
# 0                           749                  10                 1
# 1                          1574                  14                 1
# 1                          1967                   7                 0
# 2                          2355                   7                 2
# 2                          2807                   8                 0
# 7                          3262                   6                 0
# 3                          3854                   5                 0
# 5                          4390                  20                 6
# 0                          4447                   6                 2
#
#                 subscribers_net  subscribers_total     views
# followers_lost
# 0                             0                  0     128.0
# 0                             0                  0   16130.0
# 0                             0                  0   14616.0
# 0                             0                  0    4053.0
# 1                             0                  0    5153.0
# 0                             0                  0   16029.0
# 1                             3                  3   59976.0
# 0                             9                 12   76322.0
# 1                            13                 25  108962.0
# 1                             7                 32  100650.0
# 2                             5                 37  102987.0
# 2                             8                 45  134765.0
# 7                             6                 51  167608.0
# 3                             5                 56  154235.0
# 5                            14                 70  144167.0
# 0                             4                 74       NaN

# %% [raw]
# model=AutoTS(forecast_length=3, frequency='infer', ensemble='simple')

# %% [raw]
# model=model.fit(data, date_col='period_end',value_col='followers_lost',id_col=None)

# %%
prediction=model.predict()

# %%
print(forecast)
# Out:
#             followers_lost
# 2021-09-30            18.0
# 2021-10-31             0.0
# 2021-11-30             0.0

# %%
forecast
# Out:
#             followers_lost
# 2021-09-30            18.0
# 2021-10-31             0.0
# 2021-11-30             0.0

# %%
model=AutoTS(forecast_length=3, frequency='infer', ensemble='simple')

# %%
model=model.fit(data, date_col='period_end',value_col='followers_total',id_col=None)

# %%
prediction=model.predict()

# %%
forecast=prediction.forecast

# %%
print(forecast)
# Out:
#             followers_total
# 2021-09-30      4406.803737
# 2021-10-31      4501.017770
# 2021-11-30      4628.160357
